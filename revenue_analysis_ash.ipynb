# %% [markdown]
# # Pandemic Watching
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib notebook

# %%
#read xlsx file
netflix_df=pd.read_excel("Resources/Netflix_data_clean.xlsx")
netflix_df
# Out:
#         Date  Total Subs(USCAN)  Revenue(USCAN)  Total Subs(World)  \
# 0 2019-03-31               66.6            4521              148.9
# 1 2019-06-30               66.5            4923              151.6
# 2 2019-09-30               67.1            5245              158.3
# 3 2019-12-31               67.7            5467              167.3
# 4 2020-03-31               70.0            5768              182.9
# 5 2020-06-30               72.9            6148              192.9
# 6 2020-09-30               73.1            6436              195.2
# 7 2020-12-31               73.9            6644              203.7
#
#    Revenue(World)
# 0            1801
# 1            1820
# 2            1893
# 3            1981
# 4            2207
# 5            2462
# 6            2654
# 7            2822

# %%
#plot 
#x_axis=netflix_df['Date']

#revenue_uscan=netflix_df['Revenue(USCAN)']
#revenue_uscan_plt, =plt.plot(x_axis,revenue_uscan,marker="+", color='blue',linewidth=1, label="Revnue(USCAN)")

#revenue_world=netflix_df['Revenue(World)']
#revenue_world_plt, =plt.plot(x_axis,revenue_world, marker="s",color='green',linewidth=1, label="Revenue(World)")

#plt.legend(handles=[revenue_uscan_plt, revenue_world_plt], loc="best")

#add labels and title 
#plt.xlabel("Date")
#plt.ylabel("Revenue in Millions")
#plt.title("Netflix revenue in 2019 and 2020")

#plt.grid()

#plt.xticks(rotation=90)
#plt.savefig("Netflix_revenue.png")

#plt.show

# %%
#Subscribers Plot

x_axis=netflix_df['Date']

subs_uscan=netflix_df['Total Subs(USCAN)']
total_subs_uscan, =plt.plot(x_axis,subs_uscan,marker="o", color='blue',linewidth=1, label="USCAN")

subs_world=netflix_df['Total Subs(World)']
total_subs_World, =plt.plot(x_axis,subs_world,marker="^",color='green',linewidth=1,label="World")

plt.legend(handles=[total_subs_uscan, total_subs_World], loc="best")

#add labels and title 
plt.xlabel("Date")
plt.ylabel("Total Subscribers in Millions")
plt.title("Netflix Subscribers in 2019 and 2020")

plt.grid()

plt.xticks(rotation=90)
plt.savefig("Total_Subscribers.png")

plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(block=None)>

# %%
# Out:
# Figure(layout=FigureLayout(height='420px'))
